# %% [markdown]
# ## 1.Load der Python Pakete:
# Wie unter Punkt 1.1 Methoden beschrieben werden folgende Pakete benötigt und geladen

# %%
# Import the required libraries
import pandas as pd # Used for DataFrame
import numpy as np # Used for mathematical operations
from google.colab import drive # Used for accessing the data on Google Drive
import matplotlib.pyplot as plt # Used to display the data using plots, charts, etc.
from scipy import stats
import statsmodels.api as sm
import seaborn as sb

# First we need to mount our Google Drive to access our files 

drive.mount('/content/drive',force_remount=True)
# Out:
# /usr/local/lib/python3.7/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm
# Mounted at /content/drive

# %% [markdown]
# ## 2.Daten laden

# %% [markdown]
# Vorerst werden die TV-Nutzungsdaten (Figure 2. Data Flow Orange Felder)

# %%
# We have two files containing the results of surveys about Christmas Gifts Spending (one in 2020 and the other in 2021)
# Load the file paths in two variables

boosted= "/content/drive/MyDrive/CAS/Final Project/Colab/Werbeblöcke Instar boosted nach Update ab 1.1.22.xlsx"
nonboosted= "/content/drive/MyDrive/CAS/Final Project/Colab/Werbeblöcke Instar non-boosted ab 1.1.22.xlsx"

# %% [markdown]
# ## 3.Datentypen anpassen, Variablen selektieren, Datensätze mergen

# %% [markdown]
# Nun werden die Datentypen angepasst, die Veriablen selektiert und dann die zwei Datensätzen aus den zwei verschiedenen Datenerhebungsverfahren so zusammengesetzt, dass Vergleiche möglich sind

# %%
# read data
header = 1 
df_boosted = pd.read_excel(boosted, header = header, sheet_name=1)
df_nonboosted = pd.read_excel(nonboosted, header = header, sheet_name=1)

# %%
#Select the relevant columns
df_s_boosted = df_boosted[['Datum', 'Sender', 'Dauer', 'Titel', 'Planzeit', 'CH-Inhaltscode','Standard-Inhaltscode', 'SendungsID', 'b Rt-T 3+' ]]
df_s_nonboosted = df_nonboosted[['Datum', 'Sender', 'Dauer', 'Titel', 'Planzeit', 'CH-Inhaltscode','Standard-Inhaltscode', 'SendungsID', 'nb Rt-T 3+' ]]

# %%
# Key für das mergen der Datansätze erstellen
df_s_boosted = df_s_boosted.astype({"Planzeit":'str',"Datum":'str'})
df_s_nonboosted = df_s_nonboosted.astype({"Planzeit":'str',"Datum":'str'})
df_s_boosted['helpkey'] = df_s_boosted[['Datum','Sender','Planzeit']].apply(''.join, axis=1)
df_s_nonboosted['helpkey'] = df_s_nonboosted[['Datum','Sender','Planzeit']].apply(''.join, axis=1)

# %%
#Kurze Übersicht
print(df_s_boosted.dtypes)
print(df_s_nonboosted.dtypes)
# Out:
# Datum                    object
# Sender                   object
# Dauer                    object
# Titel                    object
# Planzeit                 object
# CH-Inhaltscode           object
# Standard-Inhaltscode      int64
# SendungsID                int64
# b Rt-T 3+               float64
# helpkey                  object
# dtype: object
# Datum                    object
# Sender                   object
# Dauer                    object
# Titel                    object
# Planzeit                 object
# CH-Inhaltscode           object
# Standard-Inhaltscode      int64
# SendungsID                int64
# nb Rt-T 3+              float64
# helpkey                  object
# dtype: object

# %%
# über den Key mergen
merge = df_s_nonboosted.merge(df_s_boosted, how='inner', on='helpkey')

# %%
#Doppelte Spalten bereiningen
df_s_merge = merge[['Datum_x', 'Sender_x', 'helpkey',  'Dauer_x', 'Titel_x', 'Planzeit_x', 'CH-Inhaltscode_x','Standard-Inhaltscode_x', 'SendungsID_x', 'b Rt-T 3+','nb Rt-T 3+']]

# %%
# Changing the datatype of Date, from
# Object to datetime64
df_s_merge = df_s_merge.astype({"SendungsID_x":'object', "Standard-Inhaltscode_x":'object', "Datum_x":'datetime64'})

# %%
# Setting the Date as index
df_s_merge['Datum']=df_s_merge['Datum_x']
df_s_merge = df_s_merge.set_index("Datum")

# %% [markdown]
# ## 4.Variablen berechnen

# %%
# Aus Datum Jahr, Monat und Woche ableiten
df_s_merge['Datum'] = df_s_merge.index
df_s_merge['Year'] = df_s_merge['Datum'].dt.year
df_s_merge['Month'] = df_s_merge['Datum'].dt.month
df_s_merge['Week'] = df_s_merge['Datum'].dt.isocalendar().week

# %%
df_s_merge['Veränderung'] = df_s_merge['b Rt-T 3+'] - df_s_merge['nb Rt-T 3+']

# %% [markdown]
# ## 5.Übersicht über das Analyse-File (Grundlage)

# %%
print(df_s_merge.dtypes)
df_s_merge
# Out:
# Datum_x                   datetime64[ns]
# Sender_x                          object
# helpkey                           object
# Dauer_x                           object
# Titel_x                           object
# Planzeit_x                        object
# CH-Inhaltscode_x                  object
# Standard-Inhaltscode_x            object
# SendungsID_x                      object
# b Rt-T 3+                        float64
# nb Rt-T 3+                       float64
# Datum                     datetime64[ns]
# Year                               int64
# Month                              int64
# Week                              UInt32
# Veränderung                      float64
# dtype: object
#               Datum_x  Sender_x                                helpkey  \
# Datum
# 2022-01-01 2022-01-01     SRF 1                01.01.2022SRF 109:40:00
# 2022-01-01 2022-01-01     SRF 1                01.01.2022SRF 112:52:00
# 2022-01-01 2022-01-01     SRF 1                01.01.2022SRF 111:17:00
# 2022-01-01 2022-01-01     SRF 1                01.01.2022SRF 113:05:00
# 2022-01-01 2022-01-01     SRF 1                01.01.2022SRF 114:15:00
# ...               ...       ...                                    ...
# 2022-06-30 2022-06-30  SRF info  30.06.2022SRF info1900-01-01 01:05:00
# 2022-06-30 2022-06-30  SRF info  30.06.2022SRF info1900-01-01 01:38:00
# 2022-06-30 2022-06-30  SRF info  30.06.2022SRF info1900-01-01 01:42:00
# 2022-06-30 2022-06-30    TRC_DS               30.06.2022TRC_DS19:55:00
# 2022-06-30 2022-06-30    TRC_DS               30.06.2022TRC_DS19:25:00
#
#              Dauer_x                       Titel_x           Planzeit_x  \
# Datum
# 2022-01-01  00:00:56         WERBUNG SRF 1 / 09:40             09:40:00
# 2022-01-01  00:02:26         WERBUNG SRF 1 / 11:10             12:52:00
# 2022-01-01  00:01:08         WERBUNG SRF 1 / 11:17             11:17:00
# 2022-01-01  00:02:37         WERBUNG SRF 1 / 13:35             13:05:00
# 2022-01-01  00:00:48         WERBUNG SRF 1 / 13:45             14:15:00
# ...              ...                           ...                  ...
# 2022-06-30  00:01:04      WERBUNG SRF INFO / 25:05  1900-01-01 01:05:00
# 2022-06-30  00:01:05      WERBUNG SRF INFO / 25:38  1900-01-01 01:38:00
# 2022-06-30  00:01:04      WERBUNG SRF INFO / 02:18  1900-01-01 01:42:00
# 2022-06-30  00:01:00              WERBUNG TRC NEWS             19:55:00
# 2022-06-30  00:01:00  WERBUNG TRC PRIME DONNERSTAG             19:25:00
#
#            CH-Inhaltscode_x Standard-Inhaltscode_x SendungsID_x   b Rt-T 3+  \
# Datum
# 2022-01-01              B31             9901000001     80884034   15.901589
# 2022-01-01              B31             9901000001     80884045   39.400195
# 2022-01-01              B34             9901000011     80884047   49.819677
# 2022-01-01              B31             9901000001     80884053  101.275029
# 2022-01-01              B31             9901000001     80884058   74.599106
# ...                     ...                    ...          ...         ...
# 2022-06-30              B31             9901000001     83011332    5.344969
# 2022-06-30              B38             9901000021     83011336    4.696300
# 2022-06-30              B31             9901000001     83011344    4.557900
# 2022-06-30              B31             9901000001     80921729  113.505243
# 2022-06-30              B31             9901000001     80921730   71.614388
#
#             nb Rt-T 3+      Datum  Year  Month  Week  Veränderung
# Datum
# 2022-01-01      12.070 2022-01-01  2022      1    52     3.831589
# 2022-01-01      33.916 2022-01-01  2022      1    52     5.484195
# 2022-01-01      47.938 2022-01-01  2022      1    52     1.881677
# 2022-01-01     102.926 2022-01-01  2022      1    52    -1.650971
# 2022-01-01      76.191 2022-01-01  2022      1    52    -1.591894
# ...                ...        ...   ...    ...   ...          ...
# 2022-06-30       3.816 2022-06-30  2022      6    26     1.528969
# 2022-06-30       3.816 2022-06-30  2022      6    26     0.880300
# 2022-06-30       3.816 2022-06-30  2022      6    26     0.741900
# 2022-06-30     134.068 2022-06-30  2022      6    26   -20.562757
# 2022-06-30      99.217 2022-06-30  2022      6    26   -27.602612
#
# [297265 rows x 16 columns]

# %% [markdown]
# df_contacts als Datafile für Visualisierungen festlegen

# %% [markdown]
# ## 5.Analysefile filtern

# %%
df_s_merge = df_s_merge.astype({"Month":'str', "Week":'str'})

# %%
values=['1','2','3','4','5','6']
df_contacts = df_s_merge[df_s_merge.Month.isin(values)]

# %% [markdown]
# # 6.Datenvergleich (Daten aus den zwei verschiednen Datenerhebungsverfahren)

# %% [markdown]
# ### Auf Datum

# %% [markdown]
# Betrachtung Perioden

# %%
# pivotieren
piv_datum = pd.pivot_table(df_contacts,index=["Datum_x"])

# %%
print(piv_datum.dtypes)
# Out:
# Veränderung    float64
# Year             int64
# b Rt-T 3+      float64
# nb Rt-T 3+     float64
# dtype: object

# %%
 
# Using a inbuilt style to change
# the look and feel of the plot
plt.style.use("fivethirtyeight")
 
# setting figure size to 12, 10
plt.figure(figsize=(30, 10))
 
# Labelling the axes and setting
# a title
plt.xlabel("Datum")
plt.ylabel("Kontakte TV-Werbung")
plt.title("gemessene TV Kontakte mit altem und neuen Datenerhebungsverfahren")
 
# plotting the "A" column and "A" column
# of Rolling Dataframe (window_size  = 20)
plt.plot(piv_datum["b Rt-T 3+"])
plt.plot(piv_datum["nb Rt-T 3+"])
plt.legend()
# Out:
# WARNING:matplotlib.legend:No handles with labels found to put in legend.

# %% [markdown]
# ## auf Monat

# %%
# Plot 
ax = df_contacts.plot(x=('Month'),y='b Rt-T 3+',kind="scatter",c='c')
##plt.plot(income, intercept + slope*income, 'b', label='Fitted treated line')
plt.show()

# %%
sb.set(style='whitegrid')
 
sb.boxplot(x="Month",
                y="Veränderung",
                data=df_contacts)

# %%
# pivotieren auf Monat
piv_month = pd.pivot_table(df_contacts,index=["Month"])
piv_month
# Out:
#        Veränderung  Year  b Rt-T 3+  nb Rt-T 3+
# Month
# 1         0.682176  2022  11.642617   10.960441
# 2         0.669033  2022  10.868736   10.199704
# 3         0.705804  2022  10.561982    9.856178
# 4         0.655773  2022   9.351734    8.695962
# 5         0.609351  2022   9.467781    8.858430
# 6         0.706687  2022   8.774439    8.067752

# %%
# Using a inbuilt style to change
# the look and feel of the plot
plt.style.use("fivethirtyeight")
 
# setting figure size to 12, 10
plt.figure(figsize=(20, 10))
 
# Labelling the axes and setting
# a title
plt.xlabel("Month")
plt.ylabel("Kontakte TV-Werbung")
plt.title("gemessene TV Kontakte mit altem und neuen Datenerhebungsverfahren")
 
# plotting the "A" column and "A" column
# of Rolling Dataframe (window_size  = 20)
plt.plot(piv_month["b Rt-T 3+"])
plt.plot(piv_month["nb Rt-T 3+"])
plt.legend()
# Out:
# WARNING:matplotlib.legend:No handles with labels found to put in legend.

# %%
# Using a inbuilt style to change
# the look and feel of the plot
plt.style.use("fivethirtyeight")
 
# setting figure size to 12, 10
plt.figure(figsize=(20, 10))
 
# Labelling the axes and setting
# a title
plt.xlabel("Month")
plt.ylabel("Kontakte TV-Werbung")
plt.title("gemessene TV Kontakte mit altem und neuen Datenerhebungsverfahren")
 
# plotting the "A" column and "A" column
# of Rolling Dataframe (window_size  = 20)
plt.plot(piv_month["Veränderung"], color='green')
plt.legend()
# Out:
# WARNING:matplotlib.legend:No handles with labels found to put in legend.

# %% [markdown]
# ## auf Sender

# %%
# pivotieren
piv_sender = pd.pivot_table(df_contacts,index=["Sender_x"])

# %%
piv_sender
# Out:
#                         Veränderung  Year   b Rt-T 3+  nb Rt-T 3+
# Sender_x
# 3+                        -0.187324  2022   10.153429   10.340753
# 4+                         0.226521  2022    6.034134    5.807613
# 5+                        -0.081536  2022    4.261207    4.342743
# 6+                         0.183259  2022    2.099775    1.916516
# 6ter CH                   -0.171943  2022    1.996950    2.168893
# AB3 CH                     0.188298  2022    1.877969    1.689671
# C8 CH                      0.835443  2022    2.708408    1.872965
# Cartoon Network CH         0.273178  2022    1.514410    1.241232
# DMAX CH                    0.506867  2022    2.773178    2.266311
# LFM TV                     0.039617  2022    0.145165    0.105548
# M6 CH                      1.096271  2022   12.506287   11.410016
# MySports One D             0.230270  2022    0.814603    0.584333
# MySports One F             0.105922  2022    0.295797    0.189875
# NITRO CH                  -0.202354  2022    3.586345    3.788698
# Nickelodeon Schweiz_7+     0.715460  2022    1.283950    0.568490
# ONE TV                     0.043525  2022    0.127556    0.084031
# ProSieben CH               1.719561  2022   11.160550    9.440988
# ProSieben Maxx CH          0.303155  2022    1.741808    1.438653
# Puls 8                     0.483705  2022    3.806345    3.322640
# RSI LA 1                   0.025699  2022   11.587148   11.561449
# RSI LA 2                   0.550834  2022    3.844409    3.293576
# RTL CH                     2.729708  2022   21.013434   18.283725
# RTL9 CH                    0.290918  2022    2.395125    2.104207
# RTLZWEI CH                 1.098023  2022    6.355166    5.257143
# RTS 1                      1.433246  2022   47.117132   45.683886
# RTS 2                      1.590201  2022   13.452446   11.862245
# Rouge TV                   0.130930  2022    0.466064    0.335134
# S1                         0.046370  2022    3.645863    3.599493
# SAT.1 CH                  -0.216028  2022   11.973150   12.189178
# SAT.1 Gold CH             -0.405879  2022    4.118772    4.524651
# SRF 1                      2.436124  2022  109.187070  106.750946
# SRF info                   1.145808  2022    9.549300    8.403491
# SRF zwei                   2.569208  2022   38.670603   36.101396
# SUPER RTL CH               0.121268  2022    2.386697    2.265429
# SWISS 1                    0.754124  2022    4.438178    3.684054
# Sixx CH                    0.276979  2022    2.260528    1.983549
# Sport 1 CH                 0.065968  2022    1.123626    1.057658
# Star TV                    0.030721  2022    0.270292    0.239571
# TF1 CH                     3.800153  2022   18.397589   14.597436
# TFX CH                     0.990125  2022    3.362222    2.372097
# TLC CH                     0.449140  2022    2.624993    2.175853
# TMC CH                     0.554122  2022    5.648029    5.093906
# TRC_DS                    10.233839  2022  118.765936  108.532097
# TV24                       0.421483  2022    4.571164    4.149681
# TV25                       0.497927  2022    3.851232    3.353306
# Tele 1                    -0.608866  2022    3.546078    4.154944
# Tele M1                    0.737652  2022    4.880028    4.142376
# TeleBärn                  -0.391497  2022    4.341629    4.733126
# TeleZüri                  -0.343988  2022   17.805906   18.149894
# VOX CH                     1.039116  2022   13.954250   12.915135
# W9 CH                      0.551692  2022    4.477723    3.926030
# WELT CH                    0.134886  2022    1.205288    1.070402
# blue ZOOM D                0.510683  2022    0.877208    0.366525
# kabel eins CH              0.092092  2022    5.537718    5.445626
# ntv CH                    -0.038850  2022    1.888782    1.927632
# telebasel                  0.165204  2022    0.461138    0.295934
# teleticino                 0.193968  2022    0.828709    0.634741
# tvo                       -0.075125  2022    2.935521    3.010646

# %%
print(piv_sender.dtypes)
# Out:
# Veränderung    float64
# Year             int64
# b Rt-T 3+      float64
# nb Rt-T 3+     float64
# dtype: object

# %%
piv_sender_sort = piv_sender.sort_values(by=['Veränderung'], ascending=False)
piv_sender_sort
# Out:
#                         Veränderung  Year   b Rt-T 3+  nb Rt-T 3+
# Sender_x
# TRC_DS                    10.233839  2022  118.765936  108.532097
# TF1 CH                     3.800153  2022   18.397589   14.597436
# RTL CH                     2.729708  2022   21.013434   18.283725
# SRF zwei                   2.569208  2022   38.670603   36.101396
# SRF 1                      2.436124  2022  109.187070  106.750946
# ProSieben CH               1.719561  2022   11.160550    9.440988
# RTS 2                      1.590201  2022   13.452446   11.862245
# RTS 1                      1.433246  2022   47.117132   45.683886
# SRF info                   1.145808  2022    9.549300    8.403491
# RTLZWEI CH                 1.098023  2022    6.355166    5.257143
# M6 CH                      1.096271  2022   12.506287   11.410016
# VOX CH                     1.039116  2022   13.954250   12.915135
# TFX CH                     0.990125  2022    3.362222    2.372097
# C8 CH                      0.835443  2022    2.708408    1.872965
# SWISS 1                    0.754124  2022    4.438178    3.684054
# Tele M1                    0.737652  2022    4.880028    4.142376
# Nickelodeon Schweiz_7+     0.715460  2022    1.283950    0.568490
# TMC CH                     0.554122  2022    5.648029    5.093906
# W9 CH                      0.551692  2022    4.477723    3.926030
# RSI LA 2                   0.550834  2022    3.844409    3.293576
# blue ZOOM D                0.510683  2022    0.877208    0.366525
# DMAX CH                    0.506867  2022    2.773178    2.266311
# TV25                       0.497927  2022    3.851232    3.353306
# Puls 8                     0.483705  2022    3.806345    3.322640
# TLC CH                     0.449140  2022    2.624993    2.175853
# TV24                       0.421483  2022    4.571164    4.149681
# ProSieben Maxx CH          0.303155  2022    1.741808    1.438653
# RTL9 CH                    0.290918  2022    2.395125    2.104207
# Sixx CH                    0.276979  2022    2.260528    1.983549
# Cartoon Network CH         0.273178  2022    1.514410    1.241232
# MySports One D             0.230270  2022    0.814603    0.584333
# 4+                         0.226521  2022    6.034134    5.807613
# teleticino                 0.193968  2022    0.828709    0.634741
# AB3 CH                     0.188298  2022    1.877969    1.689671
# 6+                         0.183259  2022    2.099775    1.916516
# telebasel                  0.165204  2022    0.461138    0.295934
# WELT CH                    0.134886  2022    1.205288    1.070402
# Rouge TV                   0.130930  2022    0.466064    0.335134
# SUPER RTL CH               0.121268  2022    2.386697    2.265429
# MySports One F             0.105922  2022    0.295797    0.189875
# kabel eins CH              0.092092  2022    5.537718    5.445626
# Sport 1 CH                 0.065968  2022    1.123626    1.057658
# S1                         0.046370  2022    3.645863    3.599493
# ONE TV                     0.043525  2022    0.127556    0.084031
# LFM TV                     0.039617  2022    0.145165    0.105548
# Star TV                    0.030721  2022    0.270292    0.239571
# RSI LA 1                   0.025699  2022   11.587148   11.561449
# ntv CH                    -0.038850  2022    1.888782    1.927632
# tvo                       -0.075125  2022    2.935521    3.010646
# 5+                        -0.081536  2022    4.261207    4.342743
# 6ter CH                   -0.171943  2022    1.996950    2.168893
# 3+                        -0.187324  2022   10.153429   10.340753
# NITRO CH                  -0.202354  2022    3.586345    3.788698
# SAT.1 CH                  -0.216028  2022   11.973150   12.189178
# TeleZüri                  -0.343988  2022   17.805906   18.149894
# TeleBärn                  -0.391497  2022    4.341629    4.733126
# SAT.1 Gold CH             -0.405879  2022    4.118772    4.524651
# Tele 1                    -0.608866  2022    3.546078    4.154944

# %%
values=['SRF 1','RTS 1', 'SRF zwei', 'RTL CH', 'TF1 CH', 'TeleZüri', 'VOX CH', 'RTS 2', 'M6 CH', 'SAT.1 CH']
df_sender = df_contacts[df_contacts.Sender_x.isin(values)]
print(df_sender)
# Out:
#               Datum_x Sender_x                   helpkey   Dauer_x  \
# Datum
# 2022-01-01 2022-01-01    SRF 1   01.01.2022SRF 109:40:00  00:00:56
# 2022-01-01 2022-01-01    SRF 1   01.01.2022SRF 112:52:00  00:02:26
# 2022-01-01 2022-01-01    SRF 1   01.01.2022SRF 111:17:00  00:01:08
# 2022-01-01 2022-01-01    SRF 1   01.01.2022SRF 113:05:00  00:02:37
# 2022-01-01 2022-01-01    SRF 1   01.01.2022SRF 114:15:00  00:00:48
# ...               ...      ...                       ...       ...
# 2022-06-30 2022-06-30   TF1 CH  30.06.2022TF1 CH20:42:00  00:03:14
# 2022-06-30 2022-06-30   TF1 CH  30.06.2022TF1 CH20:54:00  00:06:13
# 2022-06-30 2022-06-30   TF1 CH  30.06.2022TF1 CH21:44:00  00:06:11
# 2022-06-30 2022-06-30   TF1 CH  30.06.2022TF1 CH22:03:00  00:06:09
# 2022-06-30 2022-06-30   TF1 CH  30.06.2022TF1 CH22:13:00  00:06:07
#
#                            Titel_x Planzeit_x CH-Inhaltscode_x  \
# Datum
# 2022-01-01   WERBUNG SRF 1 / 09:40   09:40:00              B31
# 2022-01-01   WERBUNG SRF 1 / 11:10   12:52:00              B31
# 2022-01-01   WERBUNG SRF 1 / 11:17   11:17:00              B34
# 2022-01-01   WERBUNG SRF 1 / 13:35   13:05:00              B31
# 2022-01-01   WERBUNG SRF 1 / 13:45   14:15:00              B31
# ...                            ...        ...              ...
# 2022-06-30  PUB TF1 SUISSE / 20:42   20:42:00                2
# 2022-06-30  PUB TF1 SUISSE / 20:54   20:54:00                2
# 2022-06-30  PUB TF1 SUISSE / 21:44   21:44:00                2
# 2022-06-30  PUB TF1 SUISSE / 22:03   22:03:00                2
# 2022-06-30  PUB TF1 SUISSE / 22:13   22:13:00                2
#
#            Standard-Inhaltscode_x SendungsID_x   b Rt-T 3+  nb Rt-T 3+  \
# Datum
# 2022-01-01             9901000001     80884034   15.901589      12.070
# 2022-01-01             9901000001     80884045   39.400195      33.916
# 2022-01-01             9901000011     80884047   49.819677      47.938
# 2022-01-01             9901000001     80884053  101.275029     102.926
# 2022-01-01             9901000001     80884058   74.599106      76.191
# ...                           ...          ...         ...         ...
# 2022-06-30             9901000003     83009225   23.051793      17.452
# 2022-06-30             9901000003     83009233   24.736683      21.059
# 2022-06-30             9901000003     83009235   28.760183      23.968
# 2022-06-30             9901000003     83009236   29.367765      24.018
# 2022-06-30             9901000003     83009238   14.688052      13.762
#
#                 Datum  Year Month Week  Veränderung
# Datum
# 2022-01-01 2022-01-01  2022     1   52     3.831589
# 2022-01-01 2022-01-01  2022     1   52     5.484195
# 2022-01-01 2022-01-01  2022     1   52     1.881677
# 2022-01-01 2022-01-01  2022     1   52    -1.650971
# 2022-01-01 2022-01-01  2022     1   52    -1.591894
# ...               ...   ...   ...  ...          ...
# 2022-06-30 2022-06-30  2022     6   26     5.599793
# 2022-06-30 2022-06-30  2022     6   26     3.677683
# 2022-06-30 2022-06-30  2022     6   26     4.792183
# 2022-06-30 2022-06-30  2022     6   26     5.349765
# 2022-06-30 2022-06-30  2022     6   26     0.926052
#
# [54928 rows x 16 columns]

# %%
# Using a inbuilt style to change
# the look and feel of the plot
plt.style.use("fivethirtyeight")
 
# setting figure size to 12, 10
plt.figure(figsize=(40, 10))
 
# Labelling the axes and setting
# a title
plt.xlabel("Sender")
plt.ylabel("Kontakte TV-Werbung")
plt.title("gemessene TV Kontakte mit altem und neuen Datenerhebungsverfahren")
 
# plotting the "A" column and "A" column
# of Rolling Dataframe (window_size  = 20)
plt.plot(piv_sender_sort["b Rt-T 3+"])
plt.plot(piv_sender_sort["nb Rt-T 3+"])
plt.legend()
# Out:
# WARNING:matplotlib.legend:No handles with labels found to put in legend.

# %% [markdown]
# ## Statistische Vergleiche

# %%
k2, p = stats.normaltest(df_contacts['b Rt-T 3+']) # D Agostino-Pearson. 
alpha = 0.05 
print('Alpha = ',alpha)
print('p = ',p)
if p < alpha:  
     print("The null hypothesis can be rejected")
else:
  print("The null hypothesis cannot be rejected")
# Out:
# Alpha =  0.05
# p =  0.0
# The null hypothesis can be rejected

# %%
stats.mannwhitneyu(df_contacts['b Rt-T 3+'],df_contacts['nb Rt-T 3+'], alternative='two-sided')
# Out:
# MannwhitneyuResult(statistic=31905207003.5, pvalue=0.0)

# %%
values=['SRF 1','RTS 1', 'SRF zwei', 'RTL CH', 'TF1 CH', 'TeleZüri', 'VOX CH', 'RTS 2', 'M6 CH', 'SAT.1 CH']
df_sender = df_contacts[df_contacts.Sender_x.isin(values)]

# %%
values=['SRF 1']
df_contacts_srf1 = df_contacts[df_contacts.Sender_x.isin(values)]

# %%
stats.mannwhitneyu(df_contacts_srf1['b Rt-T 3+'],df_contacts_srf1['nb Rt-T 3+'], alternative='two-sided')
# Out:
# MannwhitneyuResult(statistic=15084394.0, pvalue=1.0731468680058572e-19)

# %%
values=['TF1 CH']
df_contacts_tf1 = df_contacts[df_contacts.Sender_x.isin(values)]

# %%
stats.mannwhitneyu(df_contacts_tf1['b Rt-T 3+'],df_contacts_tf1['nb Rt-T 3+'], alternative='two-sided')
# Out:
# MannwhitneyuResult(statistic=10351069.5, pvalue=6.756728879264081e-57)
